# %%
# !pip install pyrankvote
# Out:
# Requirement already satisfied: pyrankvote in /Users/anxhela/anaconda3/lib/python3.7/site-packages (2.0.0)
# Requirement already satisfied: tabulate in /Users/anxhela/anaconda3/lib/python3.7/site-packages (from pyrankvote) (0.8.7)

# %%
import pyrankvote
import ast
import pandas as pd
from pyrankvote import Candidate, Ballot


def rename_index_col_to_ballot_id(df):
    df.rename(columns={'Unnamed: 0': 'ballot_id'}, inplace=True)
    return df

def get_cand_list(df):
    list_of_unique_vals_in_dataframe = df.iloc[:, 1].value_counts().index
    cand_list = list(filter(lambda x: x != '0', list_of_unique_vals_in_dataframe))
    return cand_list

def initialize_cand_objs(cand_list):
    if isinstance(cand_list, str):
        return [Candidate(c) for c in cand_list.split(', ')]
    else:
        return [Candidate(c) for c in cand_list]

def initialize_cand_objs_in_df_cols(df):
    cands_df = df.iloc[:, 1:]  # getting all columns with candidate names in them
    cands_df = cands_df.applymap(lambda x: create_cand(x))  # making them into pyrankvote candidate objects
    cands_df['ballot_id'] = df.iloc[:, 0]  # stitching df back with ballot_ids from old dataframe
    return cands_df

def get_cands_into_single_cell(df):
    df['candidate_list'] = df.iloc[:, 1:].agg(", ".join, axis=1)
    return df

def initialize_ballot_objs(df):
    ballot_objects = []
    for index, value in enumerate(df['candidate_list']):
        ballot = Ballot(ranked_candidates=value)
        ballot_objects.append(ballot)
    return ballot_objects

def run_election(list_of_cand_objs, election_df):
    return pyrankvote.instant_runoff_voting(list_of_cand_objs, election_df['ballots'], pick_random_if_blank=True)

def rm_invalid_rows(df):
    return df[df['candidate_list'] != '0']

def run_all_steps(df):
    election_dict = {}
    
    df = df.dropna(axis=1, how='all')
    df = df.drop(['ballot_id','filename'], axis=1)
    print('df.shape',df.shape)
    df = get_cands_into_single_cell(df)

    df['candidate_list'] = df['candidate_list'].apply(lambda x: x.replace('0, ', '').replace(', 0', ''))
    df = rm_invalid_rows(df)
    df['candidate_list'] = df['candidate_list'].apply(lambda x: initialize_cand_objs(x))

    ballots = initialize_ballot_objs(df)
    df['ballots'] = ballots
    

    cand_list = get_cand_list(df)
    cand_list = initialize_cand_objs(cand_list)
    print("cand_list: ",cand_list)
#     print(df.head())
    election = run_election(cand_list, df)
    winner = election.get_winners()
    print("get_winners",winner)
    election_dict['winner'] = winner
    #df["irv_winner"] = winner
    print("rounds",len(election.rounds))
    election_dict['rounds'] = len(election.rounds)

#     open file and write results. read winners votes from file and write to df
    #print("register_round_results",election.register_round_results(election.rounds[-1]))

    print("election:", election)
    election_dict['election'] = election

#     print("election type:", type(election))
    election_dict['register']=election.register_round_results(election.rounds[-1])

    #print('hi')
    return df, election_dict




def read_votes(file, election_dict):
    with open(file, 'r') as file1:
        count = 0
        while True: 
            count += 1

            # Get next line from file 
            line = file1.readline()
            if not line: 
                break
            strip_line = line.strip()
    #         print('*',strip_line,'*')


            if 'ROUND' in strip_line or 'FINAL' in strip_line:
                start_round = True
                if 'ROUND 1' in strip_line or 'FINAL' in strip_line:
                    monitor_round=True
                    print('*',strip_line,'*')
                else:
                    monitor_round=False
            if 'ROUND' not in strip_line and  'FINAL' not in strip_line:
                start_round = False
                if winner in line and monitor_round:
                    print('*',strip_line,'*')
                    if 'firstRoundVotes' not in election_dict:
                        election_dict['firstRoundVotes']=[int(s) for s in strip_line.split() if s.isdigit()].pop()
                    else:
                        election_dict['finalRoundVotes']=[int(s) for s in strip_line.split() if s.isdigit()].pop()
                    
    file1.close()

# %%
df = pd.read_csv('master_elections.csv')
df = rename_index_col_to_ballot_id(df)
# df['irv_winner']=""
df = df[(df['filename']!="election_05-04-2020_08-39-40_5cands_12noise.csv") | (df['ballot_id']!=2767)]
df = df[(df['filename']!="election_04-30-2020_21-07-57_4_0.01.csv") | (df['ballot_id']!=20726)]
df = df[(df['filename']!="election_05-04-2020_08-40-23_5cands_16noise.csv") | (df['ballot_id']!=41363)]
master_df = df.copy(deep=True)
# Out:
# /Users/anxhela/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (5,6) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
pd.set_option('max_colwidth', 8000)
pd.options.display.max_columns = None
pd.options.display.float_format = '{:.4f}'.format
pd.options.display.max_rows = 10000

# %%
election_ids= df['filename'].unique()
#election_ids

# %%
all_elections_dict = {}

# %%
df.head()
# Out:
#    ballot_id  candidate_1  candidate_2  candidate_3  candidate_4  candidate_5  \
# 0          0  candidate_1  candidate_2  candidate_3  candidate_4  candidate_5
# 1          1  candidate_1  candidate_2  candidate_3  candidate_4  candidate_5
# 2          2  candidate_1  candidate_2  candidate_3  candidate_4  candidate_5
# 3          3  candidate_1  candidate_2  candidate_3            0            0
# 4          4  candidate_1  candidate_2  candidate_3  candidate_4  candidate_5
#
#   candidate_6                                         filename
# 0         NaN  election_05-04-2020_08-40-23_5cands_16noise.csv
# 1         NaN  election_05-04-2020_08-40-23_5cands_16noise.csv
# 2         NaN  election_05-04-2020_08-40-23_5cands_16noise.csv
# 3         NaN  election_05-04-2020_08-40-23_5cands_16noise.csv
# 4         NaN  election_05-04-2020_08-40-23_5cands_16noise.csv

# %%
election_num_dict = {}
for election_num, election in enumerate(election_ids):
    election_num_dict[election_num] = election
    print(election_num, election)
# Out:
# 0 election_05-04-2020_08-40-23_5cands_16noise.csv
# 1 election_04-30-2020_21-00-03_4_0.0225.csv
# 2 election_05-02-2020_08-18-17_5cands_3noise.csv
# 3 election_05-04-2020_08-38-34_4cands_12noise.csv
# 4 election_04-30-2020_20-59-34_4_0.0375.csv
# 5 election_04-30-2020_21-06-11_4_0.0125.csv
# 6 election_04-30-2020_21-08-19_3_0.013333333333333334.csv
# 7 election_05-04-2020_08-40-33_4cands_10noise.csv
# 8 election_05-02-2020_08-18-31_3cands_18noise.csv
# 9 election_04-30-2020_21-04-28_6_0.006666666666666667.csv
# 10 election_04-30-2020_21-08-00_4_0.0275.csv
# 11 election_05-04-2020_08-39-40_5cands_12noise.csv
# 12 election_04-30-2020_21-07-57_4_0.01.csv
# 13 election_04-30-2020_21-08-54_3_0.02.csv
# 14 election_05-02-2020_08-19-42_3cands_2noise.csv
# 15 election_05-04-2020_08-40-11_5cands_8noise.csv
# 16 election_05-04-2020_08-40-56_5cands_17noise.csv
# 17 election_05-02-2020_08-17-43_3cands_11noise.csv
# 18 election_05-02-2020_08-19-53_3cands_16noise.csv
# 19 election_05-04-2020_08-41-05_4cands_3noise.csv
# 20 election_05-02-2020_08-17-57_4cands_5noise.csv
# 21 election_05-04-2020_08-40-00_4cands_13noise.csv
# 22 election_05-02-2020_08-19-20_4cands_12noise.csv
# 23 election_05-02-2020_08-19-31_3cands_13noise.csv
# 24 election_05-04-2020_08-40-42_3cands_20noise.csv
# 25 election_05-02-2020_08-18-42_3cands_7noise.csv
# 26 election_05-04-2020_08-39-51_5cands_20noise.csv
# 27 election_04-30-2020_21-08-24_4_0.0225.csv
# 28 election_04-30-2020_20-59-59_4_0.0075.csv
# 29 election_05-02-2020_08-18-56_4cands_8noise.csv

# %% [markdown]
# Check:
# Election 11,12 failed

# %%
for election_num, election in enumerate(election_ids):
#     election_dict[election]=
    print(election_num, election)
#     if election_num ==11:
    print("***********Election: ", election_num)
    df_election = df.loc[df['filename']==election]
    #print(df_election.shape)

    temp_df,election_dict = run_all_steps(df_election)
    print(election_dict)
    if len(election_dict['winner'])==1:
        winner = election_dict['winner'][0].name
        election_dict['winner'] = winner
    else:
        print(election, "has more than one winner")
    result_file = 'out.txt'
    with open(result_file, 'w') as file1:
        print(election_dict['election'], file=file1)
    read_votes(result_file, election_dict)
    all_elections_dict[election_num] = election_dict
# Out:
# 0 election_05-04-2020_08-40-23_5cands_16noise.csv
# ***********Election:  0
# df.shape (41363, 5)
# cand_list:  [<Candidate('candidate_1')>, <Candidate('candidate_5')>, <Candidate('candidate_2')>, <Candidate('candidate_3')>, <Candidate('candidate_4')>]
# get_winners [<Candidate('candidate_1')>]
# rounds 4
# election: ROUND 1
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_1     9129  Hopeful
# candidate_5     9010  Hopeful
# candidate_2     8455  Hopeful
# candidate_3     7911  Hopeful
# candidate_4     6858  Rejected
#
# ROUND 2
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_1    10903  Hopeful
# candidate_5    10640  Hopeful
# candidate_3    10078  Hopeful
# candidate_2     9742  Rejected
# candidate_4        0  Rejected
#
# ROUND 3
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_1    14069  Hopeful
# candidate_3    13675  Hopeful
# candidate_5    13619  Rejected
# candidate_2        0  Rejected
# candidate_4        0  Rejected
#
# FINAL RESULT
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_1    20717  Elected
# candidate_3    20646  Rejected
# candidate_5        0  Rejected
# candidate_2        0  Rejected
# candidate_4        0  Rejected
#
# {'winner': [<Candidate('candidate_1')>], 'rounds': 4, 'election': <ElectionResults(5 rounds)>, 'register': None}
# * ROUND 1 *
# * candidate_1     9129  Hopeful *
# * FINAL RESULT *
# * candidate_1    20717  Elected *
# 1 election_04-30-2020_21-00-03_4_0.0225.csv
# ***********Election:  1
# df.shape (43730, 4)
# cand_list:  [<Candidate('candidate_1')>, <Candidate('candidate_3')>, <Candidate('candidate_2')>, <Candidate('candidate_4')>]
# get_winners [<Candidate('candidate_1')>]
# rounds 3
# election: ROUND 1
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_1    13918  Hopeful
# candidate_3    12693  Hopeful
# candidate_2    10097  Hopeful
# candidate_4     7022  Rejected
#
# ROUND 2
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_1    16899  Hopeful
# candidate_3    15679  Hopeful
# candidate_2    11152  Rejected
# candidate_4        0  Rejected
#
# FINAL RESULT
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_1    22957  Elected
# candidate_3    20773  Rejected
# candidate_2        0  Rejected
# candidate_4        0  Rejected
#
# {'winner': [<Candidate('candidate_1')>], 'rounds': 3, 'election': <ElectionResults(4 rounds)>, 'register': None}
# * ROUND 1 *
# * candidate_1    13918  Hopeful *
# * FINAL RESULT *
# * candidate_1    22957  Elected *
# 2 election_05-02-2020_08-18-17_5cands_3noise.csv
# ***********Election:  2
# df.shape (33485, 5)
# cand_list:  [<Candidate('candidate_4')>, <Candidate('candidate_1')>, <Candidate('candidate_2')>, <Candidate('candidate_3')>, <Candidate('candidate_5')>]
# get_winners [<Candidate('candidate_4')>]
# rounds 4
# election: ROUND 1
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_4     7502  Hopeful
# candidate_1     7177  Hopeful
# candidate_2     6848  Hopeful
# candidate_3     6384  Hopeful
# candidate_5     5574  Rejected
#
# ROUND 2
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_4     9065  Hopeful
# candidate_1     8735  Hopeful
# candidate_2     8359  Hopeful
# candidate_3     7326  Rejected
# candidate_5        0  Rejected
#
# ROUND 3
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_4    11522  Hopeful
# candidate_1    11056  Hopeful
# candidate_2    10907  Rejected
# candidate_3        0  Rejected
# candidate_5        0  Rejected
#
# FINAL RESULT
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_4    17366  Elected
# candidate_1    16119  Rejected
# candidate_2        0  Rejected
# candidate_3        0  Rejected
# candidate_5        0  Rejected
#
# {'winner': [<Candidate('candidate_4')>], 'rounds': 4, 'election': <ElectionResults(5 rounds)>, 'register': None}
# * ROUND 1 *
# * candidate_4     7502  Hopeful *
# * FINAL RESULT *
# * candidate_4    17366  Elected *
# 3 election_05-04-2020_08-38-34_4cands_12noise.csv
# ***********Election:  3
# df.shape (10066, 4)
# cand_list:  [<Candidate('candidate_1')>, <Candidate('candidate_4')>, <Candidate('candidate_2')>, <Candidate('candidate_3')>]
# get_winners [<Candidate('candidate_1')>]
# rounds 3
# election: ROUND 1
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_1     3400  Hopeful
# candidate_4     2343  Hopeful
# candidate_2     2269  Hopeful
# candidate_3     2053  Rejected
#
# ROUND 2
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_1     4476  Hopeful
# candidate_4     2896  Hopeful
# candidate_2     2693  Rejected
# candidate_3        0  Rejected
#
# FINAL RESULT
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_1     5749  Elected
# candidate_4     4316  Rejected
# candidate_2        0  Rejected
# candidate_3        0  Rejected
#
# {'winner': [<Candidate('candidate_1')>], 'rounds': 3, 'election': <ElectionResults(4 rounds)>, 'register': None}
# * ROUND 1 *
# * candidate_1     3400  Hopeful *
# * FINAL RESULT *
# * candidate_1     5749  Elected *
# 4 election_04-30-2020_20-59-34_4_0.0375.csv
# ***********Election:  4
# df.shape (41622, 4)
# cand_list:  [<Candidate('candidate_1')>, <Candidate('candidate_2')>, <Candidate('candidate_3')>, <Candidate('candidate_4')>]
# get_winners [<Candidate('candidate_2')>]
# rounds 3
# election: ROUND 1
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_2    11236  Hopeful
# candidate_1    11210  Hopeful
# candidate_3    10110  Hopeful
# candidate_4     9061  Rejected
#
# ROUND 2
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_2    15597  Hopeful
# candidate_1    14789  Hopeful
# candidate_3    11231  Rejected
# candidate_4        0  Rejected
#
# FINAL RESULT
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_2    25001  Elected
# candidate_1    16616  Rejected
# candidate_3        0  Rejected
# candidate_4        0  Rejected
#
# {'winner': [<Candidate('candidate_2')>], 'rounds': 3, 'election': <ElectionResults(4 rounds)>, 'register': None}
# * ROUND 1 *
# * candidate_2    11236  Hopeful *
# * FINAL RESULT *
# * candidate_2    25001  Elected *
# 5 election_04-30-2020_21-06-11_4_0.0125.csv
# ***********Election:  5
# df.shape (9190, 4)
# cand_list:  [<Candidate('candidate_1')>, <Candidate('candidate_4')>, <Candidate('candidate_3')>, <Candidate('candidate_2')>]
# get_winners [<Candidate('candidate_4')>]
# rounds 3
# election: ROUND 1
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_1     2731  Hopeful
# candidate_4     2637  Hopeful
# candidate_3     2104  Hopeful
# candidate_2     1718  Rejected
#
# ROUND 2
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_1     3584  Hopeful
# candidate_4     3052  Hopeful
# candidate_3     2554  Rejected
# candidate_2        0  Rejected
#
# FINAL RESULT
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_4     4774  Elected
# candidate_1     4416  Rejected
# candidate_3        0  Rejected
# candidate_2        0  Rejected
#
# {'winner': [<Candidate('candidate_4')>], 'rounds': 3, 'election': <ElectionResults(4 rounds)>, 'register': None}
# * ROUND 1 *
# * candidate_4     2637  Hopeful *
# * FINAL RESULT *
# * candidate_4     4774  Elected *
# 6 election_04-30-2020_21-08-19_3_0.013333333333333334.csv
# ***********Election:  6
# df.shape (18824, 3)
# cand_list:  [<Candidate('candidate_2')>, <Candidate('candidate_3')>, <Candidate('candidate_1')>]
# get_winners [<Candidate('candidate_3')>]
# rounds 2
# election: ROUND 1
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_2     8807  Hopeful
# candidate_3     8199  Hopeful
# candidate_1     1816  Rejected
#
# FINAL RESULT
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_3     9851  Elected
# candidate_2     8971  Rejected
# candidate_1        0  Rejected
#
# {'winner': [<Candidate('candidate_3')>], 'rounds': 2, 'election': <ElectionResults(3 rounds)>, 'register': None}
# * ROUND 1 *
# * candidate_3     8199  Hopeful *
# * FINAL RESULT *
# * candidate_3     9851  Elected *
# 7 election_05-04-2020_08-40-33_4cands_10noise.csv
# ***********Election:  7
# df.shape (31248, 4)
# cand_list:  [<Candidate('candidate_3')>, <Candidate('candidate_1')>, <Candidate('candidate_2')>, <Candidate('candidate_4')>]
# get_winners [<Candidate('candidate_3')>]
# rounds 3
# election: ROUND 1
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_3     8907  Hopeful
# candidate_1     7646  Hopeful
# candidate_2     7418  Hopeful
# candidate_4     7277  Rejected
#
# ROUND 2
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_3    11452  Hopeful
# candidate_1    10755  Hopeful
# candidate_2     9041  Rejected
# candidate_4        0  Rejected
#
# FINAL RESULT
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_3    17216  Elected
# candidate_1    14032  Rejected
# candidate_2        0  Rejected
# candidate_4        0  Rejected
#
# {'winner': [<Candidate('candidate_3')>], 'rounds': 3, 'election': <ElectionResults(4 rounds)>, 'register': None}
# * ROUND 1 *
# * candidate_3     8907  Hopeful *
# * FINAL RESULT *
# * candidate_3    17216  Elected *
# 8 election_05-02-2020_08-18-31_3cands_18noise.csv
# ***********Election:  8
# df.shape (5747, 3)
# cand_list:  [<Candidate('candidate_1')>, <Candidate('candidate_2')>, <Candidate('candidate_3')>]
# get_winners [<Candidate('candidate_2')>]
# rounds 2
# election: ROUND 1
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_1     2244  Hopeful
# candidate_2     2034  Hopeful
# candidate_3     1445  Rejected
#
# FINAL RESULT
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_2     3083  Elected
# candidate_1     2640  Rejected
# candidate_3        0  Rejected
#
# {'winner': [<Candidate('candidate_2')>], 'rounds': 2, 'election': <ElectionResults(3 rounds)>, 'register': None}
# * ROUND 1 *
# * candidate_2     2034  Hopeful *
# * FINAL RESULT *
# * candidate_2     3083  Elected *
# 9 election_04-30-2020_21-04-28_6_0.006666666666666667.csv
# ***********Election:  9
# df.shape (24981, 6)
# cand_list:  [<Candidate('candidate_6')>, <Candidate('candidate_3')>, <Candidate('candidate_1')>, <Candidate('candidate_2')>, <Candidate('candidate_5')>, <Candidate('candidate_4')>]
# get_winners [<Candidate('candidate_3')>]
# rounds 5
# election: ROUND 1
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_6     4300  Hopeful
# candidate_3     4260  Hopeful
# candidate_1     4224  Hopeful
# candidate_2     4188  Hopeful
# candidate_5     4162  Hopeful
# candidate_4     3847  Rejected
#
# ROUND 2
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_2     5095  Hopeful
# candidate_6     5068  Hopeful
# candidate_3     5030  Hopeful
# candidate_5     4912  Hopeful
# candidate_1     4876  Rejected
# candidate_4        0  Rejected
#
# ROUND 3
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_3     6496  Hopeful
# candidate_2     6237  Hopeful
# candidate_6     6156  Hopeful
# candidate_5     6092  Rejected
# candidate_1        0  Rejected
# candidate_4        0  Rejected
#
# ROUND 4
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_3     8630  Hopeful
# candidate_6     8192  Hopeful
# candidate_2     8159  Rejected
# candidate_5        0  Rejected
# candidate_1        0  Rejected
# candidate_4        0  Rejected
#
# FINAL RESULT
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_3    12649  Elected
# candidate_6    12332  Rejected
# candidate_2        0  Rejected
# candidate_5        0  Rejected
# candidate_1        0  Rejected
# candidate_4        0  Rejected
#
# {'winner': [<Candidate('candidate_3')>], 'rounds': 5, 'election': <ElectionResults(6 rounds)>, 'register': None}
# * ROUND 1 *
# * candidate_3     4260  Hopeful *
# * FINAL RESULT *
# * candidate_3    12649  Elected *
# 10 election_04-30-2020_21-08-00_4_0.0275.csv
# ***********Election:  10
# df.shape (33316, 4)
# cand_list:  [<Candidate('candidate_4')>, <Candidate('candidate_3')>, <Candidate('candidate_2')>, <Candidate('candidate_1')>]
# get_winners [<Candidate('candidate_4')>]
# rounds 3
# election: ROUND 1
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_4    10258  Hopeful
# candidate_3     9745  Hopeful
# candidate_2     8003  Hopeful
# candidate_1     5309  Rejected
#
# ROUND 2
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_3    12508  Hopeful
# candidate_4    11395  Hopeful
# candidate_2     9412  Rejected
# candidate_1        0  Rejected
#
# FINAL RESULT
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_4    17142  Elected
# candidate_3    16173  Rejected
# candidate_2        0  Rejected
# candidate_1        0  Rejected
#
# {'winner': [<Candidate('candidate_4')>], 'rounds': 3, 'election': <ElectionResults(4 rounds)>, 'register': None}
# * ROUND 1 *
# * candidate_4    10258  Hopeful *
# * FINAL RESULT *
# * candidate_4    17142  Elected *
# 11 election_05-04-2020_08-39-40_5cands_12noise.csv
# ***********Election:  11
# df.shape (2767, 5)
# cand_list:  [<Candidate('candidate_1')>, <Candidate('candidate_4')>, <Candidate('candidate_3')>, <Candidate('candidate_2')>, <Candidate('candidate_5')>]
# get_winners [<Candidate('candidate_3')>]
# rounds 4
# election: ROUND 1
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_1      593  Hopeful
# candidate_4      583  Hopeful
# candidate_3      565  Hopeful
# candidate_2      539  Hopeful
# candidate_5      487  Rejected
#
# ROUND 2
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_3      737  Hopeful
# candidate_4      722  Hopeful
# candidate_1      692  Hopeful
# candidate_2      616  Rejected
# candidate_5        0  Rejected
#
# ROUND 3
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_3      988  Hopeful
# candidate_4      921  Hopeful
# candidate_1      858  Rejected
# candidate_2        0  Rejected
# candidate_5        0  Rejected
#
# FINAL RESULT
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_3     1450  Elected
# candidate_4     1317  Rejected
# candidate_1        0  Rejected
# candidate_2        0  Rejected
# candidate_5        0  Rejected
#
# {'winner': [<Candidate('candidate_3')>], 'rounds': 4, 'election': <ElectionResults(5 rounds)>, 'register': None}
# * ROUND 1 *
# * candidate_3      565  Hopeful *
# * FINAL RESULT *
# * candidate_3     1450  Elected *
# 12 election_04-30-2020_21-07-57_4_0.01.csv
# ***********Election:  12
# df.shape (20726, 4)
# cand_list:  [<Candidate('candidate_3')>, <Candidate('candidate_4')>, <Candidate('candidate_1')>, <Candidate('candidate_2')>]
# get_winners [<Candidate('candidate_3')>]
# rounds 3
# election: ROUND 1
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_3     6130  Hopeful
# candidate_4     5288  Hopeful
# candidate_1     4751  Hopeful
# candidate_2     4557  Rejected
#
# ROUND 2
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_3     8295  Hopeful
# candidate_4     6247  Hopeful
# candidate_1     6184  Rejected
# candidate_2        0  Rejected
#
# FINAL RESULT
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_3    11272  Elected
# candidate_4     9454  Rejected
# candidate_1        0  Rejected
# candidate_2        0  Rejected
#
# {'winner': [<Candidate('candidate_3')>], 'rounds': 3, 'election': <ElectionResults(4 rounds)>, 'register': None}
# * ROUND 1 *
# * candidate_3     6130  Hopeful *
# * FINAL RESULT *
# * candidate_3    11272  Elected *
# 13 election_04-30-2020_21-08-54_3_0.02.csv
# ***********Election:  13
# df.shape (28129, 3)
# cand_list:  [<Candidate('candidate_2')>, <Candidate('candidate_1')>, <Candidate('candidate_3')>]
# get_winners [<Candidate('candidate_2')>]
# rounds 2
# election: ROUND 1
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_2    10855  Hopeful
# candidate_1    10192  Hopeful
# candidate_3     7067  Rejected
#
# FINAL RESULT
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_2    14969  Elected
# candidate_1    13145  Rejected
# candidate_3        0  Rejected
#
# {'winner': [<Candidate('candidate_2')>], 'rounds': 2, 'election': <ElectionResults(3 rounds)>, 'register': None}
# * ROUND 1 *
# * candidate_2    10855  Hopeful *
# * FINAL RESULT *
# * candidate_2    14969  Elected *
# 14 election_05-02-2020_08-19-42_3cands_2noise.csv
# ***********Election:  14
# df.shape (6363, 3)
# cand_list:  [<Candidate('candidate_1')>, <Candidate('candidate_3')>, <Candidate('candidate_2')>]
# get_winners [<Candidate('candidate_3')>]
# rounds 2
# election: ROUND 1
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_1     2553  Hopeful
# candidate_3     2166  Hopeful
# candidate_2     1644  Rejected
#
# FINAL RESULT
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_3     3730  Elected
# candidate_1     2633  Rejected
# candidate_2        0  Rejected
#
# {'winner': [<Candidate('candidate_3')>], 'rounds': 2, 'election': <ElectionResults(3 rounds)>, 'register': None}
# * ROUND 1 *
# * candidate_3     2166  Hopeful *
# * FINAL RESULT *
# * candidate_3     3730  Elected *
# 15 election_05-04-2020_08-40-11_5cands_8noise.csv
# ***********Election:  15
# df.shape (36662, 5)
# cand_list:  [<Candidate('candidate_1')>, <Candidate('candidate_4')>, <Candidate('candidate_5')>, <Candidate('candidate_3')>, <Candidate('candidate_2')>]
# get_winners [<Candidate('candidate_1')>]
# rounds 4
# election: ROUND 1
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_1     9156  Hopeful
# candidate_4     8476  Hopeful
# candidate_5     6801  Hopeful
# candidate_3     6382  Hopeful
# candidate_2     5847  Rejected
#
# ROUND 2
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_1    10398  Hopeful
# candidate_4    10295  Hopeful
# candidate_5     8304  Hopeful
# candidate_3     7665  Rejected
# candidate_2        0  Rejected
#
# ROUND 3
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_1    12951  Hopeful
# candidate_4    12344  Hopeful
# candidate_5    11367  Rejected
# candidate_3        0  Rejected
# candidate_2        0  Rejected
#
# FINAL RESULT
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_1    19230  Elected
# candidate_4    17432  Rejected
# candidate_5        0  Rejected
# candidate_3        0  Rejected
# candidate_2        0  Rejected
#
# {'winner': [<Candidate('candidate_1')>], 'rounds': 4, 'election': <ElectionResults(5 rounds)>, 'register': None}
# * ROUND 1 *
# * candidate_1     9156  Hopeful *
# * FINAL RESULT *
# * candidate_1    19230  Elected *
# 16 election_05-04-2020_08-40-56_5cands_17noise.csv
# ***********Election:  16
# df.shape (28791, 5)
# cand_list:  [<Candidate('candidate_1')>, <Candidate('candidate_5')>, <Candidate('candidate_2')>, <Candidate('candidate_3')>, <Candidate('candidate_4')>]
# get_winners [<Candidate('candidate_1')>]
# rounds 4
# election: ROUND 1
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_1     6574  Hopeful
# candidate_5     6240  Hopeful
# candidate_2     5761  Hopeful
# candidate_3     5521  Hopeful
# candidate_4     4695  Rejected
#
# ROUND 2
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_1     7830  Hopeful
# candidate_3     7211  Hopeful
# candidate_5     6949  Hopeful
# candidate_2     6801  Rejected
# candidate_4        0  Rejected
#
# ROUND 3
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_1    10075  Hopeful
# candidate_3     9700  Hopeful
# candidate_5     9016  Rejected
# candidate_2        0  Rejected
# candidate_4        0  Rejected
#
# FINAL RESULT
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_1    14872  Elected
# candidate_3    13919  Rejected
# candidate_5        0  Rejected
# candidate_2        0  Rejected
# candidate_4        0  Rejected
#
# {'winner': [<Candidate('candidate_1')>], 'rounds': 4, 'election': <ElectionResults(5 rounds)>, 'register': None}
# * ROUND 1 *
# * candidate_1     6574  Hopeful *
# * FINAL RESULT *
# * candidate_1    14872  Elected *
# 17 election_05-02-2020_08-17-43_3cands_11noise.csv
# ***********Election:  17
# df.shape (2631, 3)
# cand_list:  [<Candidate('candidate_1')>, <Candidate('candidate_2')>, <Candidate('candidate_3')>]
# get_winners [<Candidate('candidate_1')>]
# rounds 2
# election: ROUND 1
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_1     1033  Hopeful
# candidate_2     1000  Hopeful
# candidate_3      593  Rejected
#
# FINAL RESULT
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_1     1541  Elected
# candidate_2     1085  Rejected
# candidate_3        0  Rejected
#
# {'winner': [<Candidate('candidate_1')>], 'rounds': 2, 'election': <ElectionResults(3 rounds)>, 'register': None}
# * ROUND 1 *
# * candidate_1     1033  Hopeful *
# * FINAL RESULT *
# * candidate_1     1541  Elected *
# 18 election_05-02-2020_08-19-53_3cands_16noise.csv
# ***********Election:  18
# df.shape (7123, 3)
# cand_list:  [<Candidate('candidate_1')>, <Candidate('candidate_2')>, <Candidate('candidate_3')>]
# get_winners [<Candidate('candidate_2')>]
# rounds 2
# election: ROUND 1
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_1     3282  Hopeful
# candidate_2     3114  Hopeful
# candidate_3      711  Rejected
#
# FINAL RESULT
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_2     3727  Elected
# candidate_1     3380  Rejected
# candidate_3        0  Rejected
#
# {'winner': [<Candidate('candidate_2')>], 'rounds': 2, 'election': <ElectionResults(3 rounds)>, 'register': None}
# * ROUND 1 *
# * candidate_2     3114  Hopeful *
# * FINAL RESULT *
# * candidate_2     3727  Elected *
# 19 election_05-04-2020_08-41-05_4cands_3noise.csv
# ***********Election:  19
# df.shape (45385, 4)
# cand_list:  [<Candidate('candidate_2')>, <Candidate('candidate_3')>, <Candidate('candidate_4')>, <Candidate('candidate_1')>]
# get_winners [<Candidate('candidate_2')>]
# rounds 3
# election: ROUND 1
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_2    14039  Hopeful
# candidate_3    11821  Hopeful
# candidate_4    11750  Hopeful
# candidate_1     7775  Rejected
#
# ROUND 2
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_2    17015  Hopeful
# candidate_4    15185  Hopeful
# candidate_3    13185  Rejected
# candidate_1        0  Rejected
#
# FINAL RESULT
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_2    23333  Elected
# candidate_4    22052  Rejected
# candidate_3        0  Rejected
# candidate_1        0  Rejected
#
# {'winner': [<Candidate('candidate_2')>], 'rounds': 3, 'election': <ElectionResults(4 rounds)>, 'register': None}
# * ROUND 1 *
# * candidate_2    14039  Hopeful *
# * FINAL RESULT *
# * candidate_2    23333  Elected *
# 20 election_05-02-2020_08-17-57_4cands_5noise.csv
# ***********Election:  20
# df.shape (3607, 4)
# cand_list:  [<Candidate('candidate_2')>, <Candidate('candidate_1')>, <Candidate('candidate_4')>, <Candidate('candidate_3')>]
# get_winners [<Candidate('candidate_2')>]
# rounds 3
# election: ROUND 1
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_2     1216  Hopeful
# candidate_1      889  Hopeful
# candidate_4      862  Hopeful
# candidate_3      640  Rejected
#
# ROUND 2
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_2     1257  Hopeful
# candidate_1     1181  Hopeful
# candidate_4     1169  Rejected
# candidate_3        0  Rejected
#
# FINAL RESULT
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_2     1897  Elected
# candidate_1     1710  Rejected
# candidate_4        0  Rejected
# candidate_3        0  Rejected
#
# {'winner': [<Candidate('candidate_2')>], 'rounds': 3, 'election': <ElectionResults(4 rounds)>, 'register': None}
# * ROUND 1 *
# * candidate_2     1216  Hopeful *
# * FINAL RESULT *
# * candidate_2     1897  Elected *
# 21 election_05-04-2020_08-40-00_4cands_13noise.csv
# ***********Election:  21
# df.shape (16564, 4)
# cand_list:  [<Candidate('candidate_3')>, <Candidate('candidate_2')>, <Candidate('candidate_1')>, <Candidate('candidate_4')>]
# get_winners [<Candidate('candidate_3')>]
# rounds 3
# election: ROUND 1
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_3     5418  Hopeful
# candidate_2     4518  Hopeful
# candidate_1     3443  Hopeful
# candidate_4     3184  Rejected
#
# ROUND 2
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_3     6729  Hopeful
# candidate_2     5000  Hopeful
# candidate_1     4834  Rejected
# candidate_4        0  Rejected
#
# FINAL RESULT
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_3     9083  Elected
# candidate_2     7480  Rejected
# candidate_1        0  Rejected
# candidate_4        0  Rejected
#
# {'winner': [<Candidate('candidate_3')>], 'rounds': 3, 'election': <ElectionResults(4 rounds)>, 'register': None}
# * ROUND 1 *
# * candidate_3     5418  Hopeful *
# * FINAL RESULT *
# * candidate_3     9083  Elected *
# 22 election_05-02-2020_08-19-20_4cands_12noise.csv
# ***********Election:  22
# df.shape (10548, 4)
# cand_list:  [<Candidate('candidate_4')>, <Candidate('candidate_1')>, <Candidate('candidate_3')>, <Candidate('candidate_2')>]
# get_winners [<Candidate('candidate_4')>]
# rounds 3
# election: ROUND 1
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_4     3381  Hopeful
# candidate_1     2748  Hopeful
# candidate_3     2411  Hopeful
# candidate_2     2008  Rejected
#
# ROUND 2
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_4     3893  Hopeful
# candidate_1     3710  Hopeful
# candidate_3     2945  Rejected
# candidate_2        0  Rejected
#
# FINAL RESULT
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_4     5607  Elected
# candidate_1     4941  Rejected
# candidate_3        0  Rejected
# candidate_2        0  Rejected
#
# {'winner': [<Candidate('candidate_4')>], 'rounds': 3, 'election': <ElectionResults(4 rounds)>, 'register': None}
# * ROUND 1 *
# * candidate_4     3381  Hopeful *
# * FINAL RESULT *
# * candidate_4     5607  Elected *
# 23 election_05-02-2020_08-19-31_3cands_13noise.csv
# ***********Election:  23
# df.shape (13419, 3)
# cand_list:  [<Candidate('candidate_3')>, <Candidate('candidate_2')>, <Candidate('candidate_1')>]
# get_winners [<Candidate('candidate_3')>]
# rounds 2
# election: ROUND 1
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_3     6309  Hopeful
# candidate_2     5588  Hopeful
# candidate_1     1505  Rejected
#
# FINAL RESULT
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_3     6889  Elected
# candidate_2     6513  Rejected
# candidate_1        0  Rejected
#
# {'winner': [<Candidate('candidate_3')>], 'rounds': 2, 'election': <ElectionResults(3 rounds)>, 'register': None}
# * ROUND 1 *
# * candidate_3     6309  Hopeful *
# * FINAL RESULT *
# * candidate_3     6889  Elected *
# 24 election_05-04-2020_08-40-42_3cands_20noise.csv
# ***********Election:  24
# df.shape (3956, 3)
# cand_list:  [<Candidate('candidate_3')>, <Candidate('candidate_1')>, <Candidate('candidate_2')>]
# get_winners [<Candidate('candidate_1')>]
# rounds 2
# election: ROUND 1
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_3     1600  Hopeful
# candidate_1     1478  Hopeful
# candidate_2      856  Rejected
#
# FINAL RESULT
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_1     2113  Elected
# candidate_3     1821  Rejected
# candidate_2        0  Rejected
#
# {'winner': [<Candidate('candidate_1')>], 'rounds': 2, 'election': <ElectionResults(3 rounds)>, 'register': None}
# * ROUND 1 *
# * candidate_1     1478  Hopeful *
# * FINAL RESULT *
# * candidate_1     2113  Elected *
# 25 election_05-02-2020_08-18-42_3cands_7noise.csv
# ***********Election:  25
# df.shape (47446, 3)
# cand_list:  [<Candidate('candidate_3')>, <Candidate('candidate_1')>, <Candidate('candidate_2')>]
# get_winners [<Candidate('candidate_3')>]
# rounds 2
# election: ROUND 1
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_3    23128  Hopeful
# candidate_1    14927  Hopeful
# candidate_2     9359  Rejected
#
# FINAL RESULT
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_3    29804  Elected
# candidate_1    17610  Rejected
# candidate_2        0  Rejected
#
# {'winner': [<Candidate('candidate_3')>], 'rounds': 2, 'election': <ElectionResults(3 rounds)>, 'register': None}
# * ROUND 1 *
# * candidate_3    23128  Hopeful *
# * FINAL RESULT *
# * candidate_3    29804  Elected *
# 26 election_05-04-2020_08-39-51_5cands_20noise.csv
# ***********Election:  26
# df.shape (8366, 5)
# cand_list:  [<Candidate('candidate_4')>, <Candidate('candidate_2')>, <Candidate('candidate_3')>, <Candidate('candidate_1')>, <Candidate('candidate_5')>]
# get_winners [<Candidate('candidate_4')>]
# rounds 4
# election: ROUND 1
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_4     1816  Hopeful
# candidate_2     1754  Hopeful
# candidate_1     1674  Hopeful
# candidate_3     1673  Hopeful
# candidate_5     1449  Rejected
#
# ROUND 2
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_1     2199  Hopeful
# candidate_4     2192  Hopeful
# candidate_3     1998  Hopeful
# candidate_2     1977  Rejected
# candidate_5        0  Rejected
#
# ROUND 3
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_4     3041  Hopeful
# candidate_1     2773  Hopeful
# candidate_3     2552  Rejected
# candidate_2        0  Rejected
# candidate_5        0  Rejected
#
# FINAL RESULT
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_4     4250  Elected
# candidate_1     4116  Rejected
# candidate_3        0  Rejected
# candidate_2        0  Rejected
# candidate_5        0  Rejected
#
# {'winner': [<Candidate('candidate_4')>], 'rounds': 4, 'election': <ElectionResults(5 rounds)>, 'register': None}
# * ROUND 1 *
# * candidate_4     1816  Hopeful *
# * FINAL RESULT *
# * candidate_4     4250  Elected *
# 27 election_04-30-2020_21-08-24_4_0.0225.csv
# ***********Election:  27
# df.shape (3772, 4)
# cand_list:  [<Candidate('candidate_4')>, <Candidate('candidate_3')>, <Candidate('candidate_1')>, <Candidate('candidate_2')>]
# get_winners [<Candidate('candidate_4')>]
# rounds 3
# election: ROUND 1
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_4     1424  Hopeful
# candidate_3      967  Hopeful
# candidate_1      806  Hopeful
# candidate_2      575  Rejected
#
# ROUND 2
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_4     1520  Hopeful
# candidate_1     1146  Hopeful
# candidate_3     1106  Rejected
# candidate_2        0  Rejected
#
# FINAL RESULT
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_4     2029  Elected
# candidate_1     1743  Rejected
# candidate_3        0  Rejected
# candidate_2        0  Rejected
#
# {'winner': [<Candidate('candidate_4')>], 'rounds': 3, 'election': <ElectionResults(4 rounds)>, 'register': None}
# * ROUND 1 *
# * candidate_4     1424  Hopeful *
# * FINAL RESULT *
# * candidate_4     2029  Elected *
# 28 election_04-30-2020_20-59-59_4_0.0075.csv
# ***********Election:  28
# df.shape (33119, 4)
# cand_list:  [<Candidate('candidate_1')>, <Candidate('candidate_2')>, <Candidate('candidate_4')>, <Candidate('candidate_3')>, <Candidate('6')>]
# get_winners [<Candidate('candidate_1')>]
# rounds 3
# election: ROUND 1
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_1    10983  Hopeful
# candidate_2     8113  Hopeful
# candidate_4     7909  Hopeful
# candidate_3     6113  Rejected
# 6                  1  Rejected
#
# ROUND 2
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_1    13263  Hopeful
# candidate_4    10016  Hopeful
# candidate_2     9840  Rejected
# candidate_3        0  Rejected
# 6                  0  Rejected
#
# FINAL RESULT
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_1    17015  Elected
# candidate_4    16104  Rejected
# candidate_2        0  Rejected
# candidate_3        0  Rejected
# 6                  0  Rejected
#
# {'winner': [<Candidate('candidate_1')>], 'rounds': 3, 'election': <ElectionResults(4 rounds)>, 'register': None}
# * ROUND 1 *
# * candidate_1    10983  Hopeful *
# * FINAL RESULT *
# * candidate_1    17015  Elected *
# 29 election_05-02-2020_08-18-56_4cands_8noise.csv
# ***********Election:  29
# df.shape (42883, 4)
# cand_list:  [<Candidate('candidate_2')>, <Candidate('candidate_1')>, <Candidate('candidate_3')>, <Candidate('candidate_4')>, <Candidate('6')>]
# get_winners [<Candidate('candidate_1')>]
# rounds 3
# election: ROUND 1
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_1    11653  Hopeful
# candidate_2    11650  Hopeful
# candidate_3    11161  Hopeful
# candidate_4     8418  Rejected
# 6                  1  Rejected
#
# ROUND 2
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_1    15393  Hopeful
# candidate_2    13756  Hopeful
# candidate_3    13734  Rejected
# candidate_4        0  Rejected
# 6                  0  Rejected
#
# FINAL RESULT
# Candidate      Votes  Status
# -----------  -------  --------
# candidate_1    22784  Elected
# candidate_2    20099  Rejected
# candidate_3        0  Rejected
# candidate_4        0  Rejected
# 6                  0  Rejected
#
# {'winner': [<Candidate('candidate_1')>], 'rounds': 3, 'election': <ElectionResults(4 rounds)>, 'register': None}
# * ROUND 1 *
# * candidate_1    11653  Hopeful *
# * FINAL RESULT *
# * candidate_1    22784  Elected *

# %%
all_elections_dict
# Out:
# {0: {'winner': 'candidate_1',
#   'rounds': 4,
#   'election': <ElectionResults(5 rounds)>,
#   'register': None,
#   'firstRoundVotes': 9129,
#   'finalRoundVotes': 20717},
#  1: {'winner': 'candidate_1',
#   'rounds': 3,
#   'election': <ElectionResults(4 rounds)>,
#   'register': None,
#   'firstRoundVotes': 13918,
#   'finalRoundVotes': 22957},
#  2: {'winner': 'candidate_4',
#   'rounds': 4,
#   'election': <ElectionResults(5 rounds)>,
#   'register': None,
#   'firstRoundVotes': 7502,
#   'finalRoundVotes': 17366},
#  3: {'winner': 'candidate_1',
#   'rounds': 3,
#   'election': <ElectionResults(4 rounds)>,
#   'register': None,
#   'firstRoundVotes': 3400,
#   'finalRoundVotes': 5749},
#  4: {'winner': 'candidate_2',
#   'rounds': 3,
#   'election': <ElectionResults(4 rounds)>,
#   'register': None,
#   'firstRoundVotes': 11236,
#   'finalRoundVotes': 25001},
#  5: {'winner': 'candidate_4',
#   'rounds': 3,
#   'election': <ElectionResults(4 rounds)>,
#   'register': None,
#   'firstRoundVotes': 2637,
#   'finalRoundVotes': 4774},
#  6: {'winner': 'candidate_3',
#   'rounds': 2,
#   'election': <ElectionResults(3 rounds)>,
#   'register': None,
#   'firstRoundVotes': 8199,
#   'finalRoundVotes': 9851},
#  7: {'winner': 'candidate_3',
#   'rounds': 3,
#   'election': <ElectionResults(4 rounds)>,
#   'register': None,
#   'firstRoundVotes': 8907,
#   'finalRoundVotes': 17216},
#  8: {'winner': 'candidate_2',
#   'rounds': 2,
#   'election': <ElectionResults(3 rounds)>,
#   'register': None,
#   'firstRoundVotes': 2034,
#   'finalRoundVotes': 3083},
#  9: {'winner': 'candidate_3',
#   'rounds': 5,
#   'election': <ElectionResults(6 rounds)>,
#   'register': None,
#   'firstRoundVotes': 4260,
#   'finalRoundVotes': 12649},
#  10: {'winner': 'candidate_4',
#   'rounds': 3,
#   'election': <ElectionResults(4 rounds)>,
#   'register': None,
#   'firstRoundVotes': 10258,
#   'finalRoundVotes': 17142},
#  11: {'winner': 'candidate_3',
#   'rounds': 4,
#   'election': <ElectionResults(5 rounds)>,
#   'register': None,
#   'firstRoundVotes': 565,
#   'finalRoundVotes': 1450},
#  12: {'winner': 'candidate_3',
#   'rounds': 3,
#   'election': <ElectionResults(4 rounds)>,
#   'register': None,
#   'firstRoundVotes': 6130,
#   'finalRoundVotes': 11272},
#  13: {'winner': 'candidate_2',
#   'rounds': 2,
#   'election': <ElectionResults(3 rounds)>,
#   'register': None,
#   'firstRoundVotes': 10855,
#   'finalRoundVotes': 14969},
#  14: {'winner': 'candidate_3',
#   'rounds': 2,
#   'election': <ElectionResults(3 rounds)>,
#   'register': None,
#   'firstRoundVotes': 2166,
#   'finalRoundVotes': 3730},
#  15: {'winner': 'candidate_1',
#   'rounds': 4,
#   'election': <ElectionResults(5 rounds)>,
#   'register': None,
#   'firstRoundVotes': 9156,
#   'finalRoundVotes': 19230},
#  16: {'winner': 'candidate_1',
#   'rounds': 4,
#   'election': <ElectionResults(5 rounds)>,
#   'register': None,
#   'firstRoundVotes': 6574,
#   'finalRoundVotes': 14872},
#  17: {'winner': 'candidate_1',
#   'rounds': 2,
#   'election': <ElectionResults(3 rounds)>,
#   'register': None,
#   'firstRoundVotes': 1033,
#   'finalRoundVotes': 1541},
#  18: {'winner': 'candidate_2',
#   'rounds': 2,
#   'election': <ElectionResults(3 rounds)>,
#   'register': None,
#   'firstRoundVotes': 3114,
#   'finalRoundVotes': 3727},
#  19: {'winner': 'candidate_2',
#   'rounds': 3,
#   'election': <ElectionResults(4 rounds)>,
#   'register': None,
#   'firstRoundVotes': 14039,
#   'finalRoundVotes': 23333},
#  20: {'winner': 'candidate_2',
#   'rounds': 3,
#   'election': <ElectionResults(4 rounds)>,
#   'register': None,
#   'firstRoundVotes': 1216,
#   'finalRoundVotes': 1897},
#  21: {'winner': 'candidate_3',
#   'rounds': 3,
#   'election': <ElectionResults(4 rounds)>,
#   'register': None,
#   'firstRoundVotes': 5418,
#   'finalRoundVotes': 9083},
#  22: {'winner': 'candidate_4',
#   'rounds': 3,
#   'election': <ElectionResults(4 rounds)>,
#   'register': None,
#   'firstRoundVotes': 3381,
#   'finalRoundVotes': 5607},
#  23: {'winner': 'candidate_3',
#   'rounds': 2,
#   'election': <ElectionResults(3 rounds)>,
#   'register': None,
#   'firstRoundVotes': 6309,
#   'finalRoundVotes': 6889},
#  24: {'winner': 'candidate_1',
#   'rounds': 2,
#   'election': <ElectionResults(3 rounds)>,
#   'register': None,
#   'firstRoundVotes': 1478,
#   'finalRoundVotes': 2113},
#  25: {'winner': 'candidate_3',
#   'rounds': 2,
#   'election': <ElectionResults(3 rounds)>,
#   'register': None,
#   'firstRoundVotes': 23128,
#   'finalRoundVotes': 29804},
#  26: {'winner': 'candidate_4',
#   'rounds': 4,
#   'election': <ElectionResults(5 rounds)>,
#   'register': None,
#   'firstRoundVotes': 1816,
#   'finalRoundVotes': 4250},
#  27: {'winner': 'candidate_4',
#   'rounds': 3,
#   'election': <ElectionResults(4 rounds)>,
#   'register': None,
#   'firstRoundVotes': 1424,
#   'finalRoundVotes': 2029},
#  28: {'winner': 'candidate_1',
#   'rounds': 3,
#   'election': <ElectionResults(4 rounds)>,
#   'register': None,
#   'firstRoundVotes': 10983,
#   'finalRoundVotes': 17015},
#  29: {'winner': 'candidate_1',
#   'rounds': 3,
#   'election': <ElectionResults(4 rounds)>,
#   'register': None,
#   'firstRoundVotes': 11653,
#   'finalRoundVotes': 22784}}

# %%
election_results_df=pd.DataFrame()
election_results_list=[]

# %%
for key,val in all_elections_dict.items():
    val['election_id']=election_num_dict[key]
    del val['register']
    del val['election']
    print(val)

    election_results_list.append(val)
# Out:
# {'winner': 'candidate_1', 'rounds': 4, 'firstRoundVotes': 9129, 'finalRoundVotes': 20693, 'election_id': 'election_05-04-2020_08-40-23_5cands_16noise.csv'}
# {'winner': 'candidate_1', 'rounds': 3, 'firstRoundVotes': 13918, 'finalRoundVotes': 22931, 'election_id': 'election_04-30-2020_21-00-03_4_0.0225.csv'}
# {'winner': 'candidate_4', 'rounds': 4, 'firstRoundVotes': 7502, 'finalRoundVotes': 17359, 'election_id': 'election_05-02-2020_08-18-17_5cands_3noise.csv'}
# {'winner': 'candidate_1', 'rounds': 3, 'firstRoundVotes': 3400, 'finalRoundVotes': 5760, 'election_id': 'election_05-04-2020_08-38-34_4cands_12noise.csv'}
# {'winner': 'candidate_2', 'rounds': 3, 'firstRoundVotes': 11236, 'finalRoundVotes': 24984, 'election_id': 'election_04-30-2020_20-59-34_4_0.0375.csv'}
# {'winner': 'candidate_4', 'rounds': 3, 'firstRoundVotes': 2637, 'finalRoundVotes': 4770, 'election_id': 'election_04-30-2020_21-06-11_4_0.0125.csv'}
# {'winner': 'candidate_3', 'rounds': 2, 'firstRoundVotes': 8199, 'finalRoundVotes': 9857, 'election_id': 'election_04-30-2020_21-08-19_3_0.013333333333333334.csv'}
# {'winner': 'candidate_3', 'rounds': 3, 'firstRoundVotes': 8907, 'finalRoundVotes': 17220, 'election_id': 'election_05-04-2020_08-40-33_4cands_10noise.csv'}
# {'winner': 'candidate_2', 'rounds': 2, 'firstRoundVotes': 2034, 'finalRoundVotes': 3085, 'election_id': 'election_05-02-2020_08-18-31_3cands_18noise.csv'}
# {'winner': 'candidate_3', 'rounds': 5, 'firstRoundVotes': 4260, 'finalRoundVotes': 12651, 'election_id': 'election_04-30-2020_21-04-28_6_0.006666666666666667.csv'}
# {'winner': 'candidate_4', 'rounds': 3, 'firstRoundVotes': 10258, 'finalRoundVotes': 17148, 'election_id': 'election_04-30-2020_21-08-00_4_0.0275.csv'}
# {'winner': 'candidate_3', 'rounds': 4, 'firstRoundVotes': 565, 'finalRoundVotes': 1458, 'election_id': 'election_05-04-2020_08-39-40_5cands_12noise.csv'}
# {'winner': 'candidate_3', 'rounds': 3, 'firstRoundVotes': 6130, 'finalRoundVotes': 11272, 'election_id': 'election_04-30-2020_21-07-57_4_0.01.csv'}
# {'winner': 'candidate_2', 'rounds': 2, 'firstRoundVotes': 10855, 'finalRoundVotes': 14981, 'election_id': 'election_04-30-2020_21-08-54_3_0.02.csv'}
# {'winner': 'candidate_3', 'rounds': 2, 'firstRoundVotes': 2166, 'finalRoundVotes': 3730, 'election_id': 'election_05-02-2020_08-19-42_3cands_2noise.csv'}
# {'winner': 'candidate_1', 'rounds': 4, 'firstRoundVotes': 9156, 'finalRoundVotes': 19219, 'election_id': 'election_05-04-2020_08-40-11_5cands_8noise.csv'}
# {'winner': 'candidate_1', 'rounds': 4, 'firstRoundVotes': 6574, 'finalRoundVotes': 14843, 'election_id': 'election_05-04-2020_08-40-56_5cands_17noise.csv'}
# {'winner': 'candidate_1', 'rounds': 2, 'firstRoundVotes': 1033, 'finalRoundVotes': 1543, 'election_id': 'election_05-02-2020_08-17-43_3cands_11noise.csv'}
# {'winner': 'candidate_2', 'rounds': 2, 'firstRoundVotes': 3114, 'finalRoundVotes': 3728, 'election_id': 'election_05-02-2020_08-19-53_3cands_16noise.csv'}
# {'winner': 'candidate_2', 'rounds': 3, 'firstRoundVotes': 14039, 'finalRoundVotes': 23342, 'election_id': 'election_05-04-2020_08-41-05_4cands_3noise.csv'}
# {'winner': 'candidate_2', 'rounds': 3, 'firstRoundVotes': 1216, 'finalRoundVotes': 1891, 'election_id': 'election_05-02-2020_08-17-57_4cands_5noise.csv'}
# {'winner': 'candidate_3', 'rounds': 3, 'firstRoundVotes': 5418, 'finalRoundVotes': 9094, 'election_id': 'election_05-04-2020_08-40-00_4cands_13noise.csv'}
# {'winner': 'candidate_4', 'rounds': 3, 'firstRoundVotes': 3381, 'finalRoundVotes': 5611, 'election_id': 'election_05-02-2020_08-19-20_4cands_12noise.csv'}
# {'winner': 'candidate_3', 'rounds': 2, 'firstRoundVotes': 6309, 'finalRoundVotes': 6885, 'election_id': 'election_05-02-2020_08-19-31_3cands_13noise.csv'}
# {'winner': 'candidate_1', 'rounds': 2, 'firstRoundVotes': 1478, 'finalRoundVotes': 2115, 'election_id': 'election_05-04-2020_08-40-42_3cands_20noise.csv'}
# {'winner': 'candidate_3', 'rounds': 2, 'firstRoundVotes': 23128, 'finalRoundVotes': 29824, 'election_id': 'election_05-02-2020_08-18-42_3cands_7noise.csv'}
# {'winner': 'candidate_4', 'rounds': 4, 'firstRoundVotes': 1816, 'finalRoundVotes': 4256, 'election_id': 'election_05-04-2020_08-39-51_5cands_20noise.csv'}
# {'winner': 'candidate_4', 'rounds': 3, 'firstRoundVotes': 1424, 'finalRoundVotes': 2028, 'election_id': 'election_04-30-2020_21-08-24_4_0.0225.csv'}
# {'winner': 'candidate_1', 'rounds': 3, 'firstRoundVotes': 10983, 'finalRoundVotes': 17000, 'election_id': 'election_04-30-2020_20-59-59_4_0.0075.csv'}
# {'winner': 'candidate_1', 'rounds': 3, 'firstRoundVotes': 11653, 'finalRoundVotes': 22801, 'election_id': 'election_05-02-2020_08-18-56_4cands_8noise.csv'}

# %%
election_results_df = pd.DataFrame(election_results_list)
election_results_df.to_csv('election_results.csv', index=False)

# %%
election_results_df
# Out:
#          winner  rounds  firstRoundVotes  finalRoundVotes  \
# 0   candidate_1       4             9129            20693
# 1   candidate_1       3            13918            22931
# 2   candidate_4       4             7502            17359
# 3   candidate_1       3             3400             5760
# 4   candidate_2       3            11236            24984
# 5   candidate_4       3             2637             4770
# 6   candidate_3       2             8199             9857
# 7   candidate_3       3             8907            17220
# 8   candidate_2       2             2034             3085
# 9   candidate_3       5             4260            12651
# 10  candidate_4       3            10258            17148
# 11  candidate_3       4              565             1458
# 12  candidate_3       3             6130            11272
# 13  candidate_2       2            10855            14981
# 14  candidate_3       2             2166             3730
# 15  candidate_1       4             9156            19219
# 16  candidate_1       4             6574            14843
# 17  candidate_1       2             1033             1543
# 18  candidate_2       2             3114             3728
# 19  candidate_2       3            14039            23342
# 20  candidate_2       3             1216             1891
# 21  candidate_3       3             5418             9094
# 22  candidate_4       3             3381             5611
# 23  candidate_3       2             6309             6885
# 24  candidate_1       2             1478             2115
# 25  candidate_3       2            23128            29824
# 26  candidate_4       4             1816             4256
# 27  candidate_4       3             1424             2028
# 28  candidate_1       3            10983            17000
# 29  candidate_1       3            11653            22801
#
#                                                 election_id
# 0           election_05-04-2020_08-40-23_5cands_16noise.csv
# 1                 election_04-30-2020_21-00-03_4_0.0225.csv
# 2            election_05-02-2020_08-18-17_5cands_3noise.csv
# 3           election_05-04-2020_08-38-34_4cands_12noise.csv
# 4                 election_04-30-2020_20-59-34_4_0.0375.csv
# 5                 election_04-30-2020_21-06-11_4_0.0125.csv
# 6   election_04-30-2020_21-08-19_3_0.013333333333333334.csv
# 7           election_05-04-2020_08-40-33_4cands_10noise.csv
# 8           election_05-02-2020_08-18-31_3cands_18noise.csv
# 9   election_04-30-2020_21-04-28_6_0.006666666666666667.csv
# 10                election_04-30-2020_21-08-00_4_0.0275.csv
# 11          election_05-04-2020_08-39-40_5cands_12noise.csv
# 12                  election_04-30-2020_21-07-57_4_0.01.csv
# 13                  election_04-30-2020_21-08-54_3_0.02.csv
# 14           election_05-02-2020_08-19-42_3cands_2noise.csv
# 15           election_05-04-2020_08-40-11_5cands_8noise.csv
# 16          election_05-04-2020_08-40-56_5cands_17noise.csv
# 17          election_05-02-2020_08-17-43_3cands_11noise.csv
# 18          election_05-02-2020_08-19-53_3cands_16noise.csv
# 19           election_05-04-2020_08-41-05_4cands_3noise.csv
# 20           election_05-02-2020_08-17-57_4cands_5noise.csv
# 21          election_05-04-2020_08-40-00_4cands_13noise.csv
# 22          election_05-02-2020_08-19-20_4cands_12noise.csv
# 23          election_05-02-2020_08-19-31_3cands_13noise.csv
# 24          election_05-04-2020_08-40-42_3cands_20noise.csv
# 25           election_05-02-2020_08-18-42_3cands_7noise.csv
# 26          election_05-04-2020_08-39-51_5cands_20noise.csv
# 27                election_04-30-2020_21-08-24_4_0.0225.csv
# 28                election_04-30-2020_20-59-59_4_0.0075.csv
# 29           election_05-02-2020_08-18-56_4cands_8noise.csv
