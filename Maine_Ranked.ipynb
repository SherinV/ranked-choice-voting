# %%
# %load_ext nb_black

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sb

df = pd.read_excel("congressd2-1.xlsx")

# %%
df.head()
# Out:
#    Cast Vote Record Precinct          Ballot Style  \
# 0              8787  Rumford  DEM Ballot Style 176
# 1              8788  Rumford  DEM Ballot Style 176
# 2              8792  Rumford  DEM Ballot Style 176
# 3              8795  Rumford  DEM Ballot Style 176
# 4              8796  Rumford  DEM Ballot Style 176
#
#   DEM Rep. to Congress 1st Choice District 2 (5739)  \
# 0                            Olson, Craig R. (5472)
# 1                           Golden, Jared F. (5471)
# 2                            Olson, Craig R. (5472)
# 3                                         undervote
# 4                                         undervote
#
#   DEM Rep. to Congress 2nd Choice District 2 (5742)  \
# 0                           Golden, Jared F. (5803)
# 1                           Golden, Jared F. (5803)
# 2                                         undervote
# 3                                         undervote
# 4                                         undervote
#
# ...

# %%
df["DEM Rep. to Congress 1st Choice District 2 (5739)"].unique()
# Out:
# array(['Olson, Craig R. (5472)', 'Golden, Jared F. (5471)', 'undervote',
#        'St. Clair, Lucas R. (5474)', 'Fulford, Jonathan S. (5470)',
#        'overvote'], dtype=object)

# %%
df_choices = df[
    [
        "DEM Rep. to Congress 1st Choice District 2 (5739)",
        "DEM Rep. to Congress 2nd Choice District 2 (5742)",
        "DEM Rep. to Congress 3rd Choice District 2 (5745)",
        "DEM Rep. to Congress 4th Choice District 2 (5748)",
        "DEM Rep. to Congress 5th Choice District 2 (5751)",
    ]
]

# %%
df.head()
# Out:
#    Cast Vote Record Precinct          Ballot Style  \
# 0              8787  Rumford  DEM Ballot Style 176
# 1              8788  Rumford  DEM Ballot Style 176
# 2              8792  Rumford  DEM Ballot Style 176
# 3              8795  Rumford  DEM Ballot Style 176
# 4              8796  Rumford  DEM Ballot Style 176
#
#   DEM Rep. to Congress 1st Choice District 2 (5739)  \
# 0                            Olson, Craig R. (5472)
# 1                           Golden, Jared F. (5471)
# 2                            Olson, Craig R. (5472)
# 3                                         undervote
# 4                                         undervote
#
#   DEM Rep. to Congress 2nd Choice District 2 (5742)  \
# 0                           Golden, Jared F. (5803)
# 1                           Golden, Jared F. (5803)
# 2                                         undervote
# 3                                         undervote
# 4                                         undervote
#
# ...

# %%
df["1 Choice"] = df["DEM Rep. to Congress 1st Choice District 2 (5739)"]
df["2 Choice"] = df["DEM Rep. to Congress 2nd Choice District 2 (5742)"]
df["3 Choice"] = df["DEM Rep. to Congress 3rd Choice District 2 (5745)"]
df["4 Choice"] = df["DEM Rep. to Congress 4th Choice District 2 (5748)"]
df["5 Choice"] = df["DEM Rep. to Congress 5th Choice District 2 (5751)"]

# %%
df.drop(
    [
        "DEM Rep. to Congress 1st Choice District 2 (5739)",
        "DEM Rep. to Congress 2nd Choice District 2 (5742)",
        "DEM Rep. to Congress 3rd Choice District 2 (5745)",
        "DEM Rep. to Congress 4th Choice District 2 (5748)",
        "DEM Rep. to Congress 5th Choice District 2 (5751)",
    ],
    axis=1,
    inplace=True,
)

# %%
df.replace({"undervote": np.NaN, "overvote": np.NaN}, inplace=True)

# %%
df.isnull().sum()
# Out:
# Cast Vote Record        0
# Precinct                0
# Ballot Style            0
# 1 Choice             5778
# 2 Choice            17361
# 3 Choice            26234
# 4 Choice            34759
# 5 Choice            49012
# dtype: int64

# %%
df.dropna(axis=0)
# Out:
#        Cast Vote Record                        Precinct          Ballot Style  \
# 0                  8787                         Rumford  DEM Ballot Style 176
# 86                 9083                         Rumford  DEM Ballot Style 176
# 563               82689                         Machias  DEM Ballot Style 101
# 710               83284                          Calais   DEM Ballot Style 32
# 746               83470                          Calais   DEM Ballot Style 32
# 757               83516                          Calais   DEM Ballot Style 32
# 815               83811                          Calais   DEM Ballot Style 32
# 863               84043                     Cherryfield    DEM Ballot Style 4
# 1104              85242                       Searsport  DEM Ballot Style 124
# 1227              85744                    Lincolnville   DEM Ballot Style 43
# 1350              86165                    Lincolnville   DEM Ballot Style 43
# ...

# %%
df["1 Choice"].value_counts()
# Out:
# Golden, Jared F. (5471)        20847
# St. Clair, Lucas R. (5474)     17601
# Olson, Craig R. (5472)          3896
# Fulford, Jonathan S. (5470)     2418
# Name: 1 Choice, dtype: int64

# %%
df["2 Choice"].value_counts()
# Out:
# St. Clair, Lucas R. (5805)     11084
# Golden, Jared F. (5803)        10151
# Olson, Craig R. (5804)          8428
# Fulford, Jonathan S. (5802)     3516
# Name: 2 Choice, dtype: int64

# %%
df["3 Choice"].value_counts()
# Out:
# Olson, Craig R. (5808)         10527
# Fulford, Jonathan S. (5806)     5169
# Golden, Jared F. (5807)         4649
# St. Clair, Lucas R. (5809)      3961
# Name: 3 Choice, dtype: int64

# %%
df["4 Choice"].value_counts()
# Out:
# Fulford, Jonathan S. (5810)    7507
# St. Clair, Lucas R. (5813)     3219
# Olson, Craig R. (5812)         3179
# Golden, Jared F. (5811)        1876
# Name: 4 Choice, dtype: int64

# %%
df["5 Choice"].value_counts()
# Out:
# St. Clair, Lucas R. (5817)     599
# Fulford, Jonathan S. (5814)    409
# Golden, Jared F. (5815)        334
# Olson, Craig R. (5816)         186
# Name: 5 Choice, dtype: int64

# %%
df = df.dropna(subset=["1 Choice"], axis=0)


df["1 Choice"].replace(
    {
        "Golden, Jared F. (5471)": 1,
        "St. Clair, Lucas R. (5474)": 2,
        "Olson, Craig R. (5472)": 3,
        "Fulford, Jonathan S. (5470)": 4,
    },
    inplace=True,
)
y = df["1 Choice"]


df_choices = df[["2 Choice", "3 Choice", "4 Choice", "5 Choice"]]
for choice in df_choices:
    df = pd.concat(
        [
            df.drop(choice, axis=1),
            pd.get_dummies(df[choice], prefix=choice, prefix_sep="_", drop_first=True),
        ],
        axis=1,
    )


X = df

# %%
df.drop(["Cast Vote Record", "Precinct", "Ballot Style"], axis=1, inplace=True)

# %%
import seaborn as sb

sb.heatmap(df.corr())
